# %%
import os
os.chdir('NNDIAL')

# %%
# %run nndial.py -config config/NDM.cfg -mode interact
# Out:
# loading net from file model/CamRest.NDM.model ...
# 	prepare slot value templates ...
# 	formatting DB ...
# 	setting up vocab, finishing ... 99.85%
# 	semi-supervised action examples: 0.00%
# 	loading semi labels from file ... finishing 100.00%
# 	Corpus VMC       : 97.34%
# 	Corpus Success   : 91.57%
#
# ...
# Data statistics
# ...
# Train    : 405
# Valid    : 135
# Test     : 136
# ...
# Voc      : 598
# ...
# Venue    : 68
# ...
# init n2n SDS ...
# 	init lstm encoder ...
# 	init rnn requestable trackers ...
# 	init OfferChange tracker ...
# 	init rnn informable trackers ...
# 	init normal policy network ...
# 	init lstm decoder ...
# ...
# 	Starting Interaction
# ...
# [User]:		I would like afghan food
# User Input :	i would like afghan food
# Belief Tracker :
#   |                    Informable                    |
#   |       Prediction	Prob.	        Ground Truth |
#   |     ------------	-----	        ------------ |
#   |        area=none	0.964 |
#   |      food=afghan	1.000 |
#   |  pricerange=none	0.652 |
# ...

# %%
os.chdir('../NNDIAL_Boston')

# %%
# %run nndial.py -config config/NDM.cfg -mode interact
# Out:
# loading net from file model/CamRest.NDM.model ...
# 	prepare slot value templates ...
# 	formatting DB ...
# 	setting up vocab, finishing ... 99.85%
# 	semi-supervised action examples: 0.00%
# 	loading semi labels from file ... finishing 100.00%
# 	Corpus VMC       : 97.34%
# 	Corpus Success   : 91.57%
#
# ...
# Data statistics
# ...
# Train    : 405
# Valid    : 135
# Test     : 136
# ...
# Voc      : 597
# ...
# Venue    : 158
# ...
# init n2n SDS ...
# 	init lstm encoder ...
# 	init rnn requestable trackers ...
# 	init OfferChange tracker ...
# 	init rnn informable trackers ...
# 	init normal policy network ...
# 	init lstm decoder ...
# ...
# 	Starting Interaction
# ...
# [User]:		I would like afghan food
# User Input :	i would like afghan food
# Belief Tracker :
#   |                    Informable                    |
#   |       Prediction	Prob.	        Ground Truth |
#   |     ------------	-----	        ------------ |
#   |        area=none	0.964 |
#   |      food=afghan	1.000 |
#   |  pricerange=none	0.652 |
# ...
